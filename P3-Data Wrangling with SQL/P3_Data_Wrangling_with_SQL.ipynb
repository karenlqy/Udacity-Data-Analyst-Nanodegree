# %% [markdown]
# ## OpenStreetMap Data Case Study with SQL

# %% [markdown]
# Author: Qingyu Li

# %% [markdown]
# Date: Sep 26 2017

# %% [markdown]
# ## 1. Map Area

# %% [markdown]
# Philadelphia, United States

# %% [markdown]
# - The OpenStreetMap Project: https://www.openstreetmap.org/relation/188022

# %% [markdown]
# - Data Extract: https://mapzen.com/data/metro-extracts/metro/philadelphia_pennsylvania/

# %% [markdown]
# I have lived in Philadelphia for a while and I would like to learn more about this fun city.

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

# %% [markdown]
# ## 2. Data Check and Cleaning

# %% [markdown]
# After downloading the dataset for Philadelphia, we select a sample of the datafile and look for areas that need additional cleaning:
# - Inconsistency in street name: 'St' for 'Street', 'Pkwy' for 'Parkway'. We need to update these names to make the street name consistent across all data points
# - Misspelling of street names: 'Lane' is spelled as 'Line', 'Street' spelled as 'Sstreets',etc.
# - City and state name are included in the street name. For example, "Baltimore Pike, Springfield, PA".

# %% [markdown]
# ### Auditing Street Names

# %% [markdown]
# We use the audit function to return a list of the street names and collect a list of abbriviations that need to be updated.

# %%
OSMFILE = "philadelphia_pennsylvania.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

pprint.pprint(dict(audit(OSMFILE)))
# Out:
# {'1': set(['Bloomfield Dr, Unit 1',
#            'Route 1',
#            'S Newtown Street Rd #1',
#            'Sansom St #1',
#            'Walnut St #1']),
#  '111': set(['South Clinton Avenue Ste. 111']),
#  '118': set(['Upland Ave #118']),
#  '168': set(['Marlton Pike East Ste. 168']),
#  '17': set(['Lancaster Avenue #17']),
#  '19047': set(['200 Manor Ave. Langhorne, PA 19047',
#                '2245 E. Lincoln Hwy, Langhorne, PA 19047',
#                '2275 E Lincoln Hwy, Langhorne, PA 19047',
#                '2300  East Lincoln Highway, Pennsylvania 19047']),
#  '19067': set(['East Trenton Avenue Morrisville, PA 19067']),
#  '2': set(['Buck Rd #2']),
#  '205': set(['Office Center Dr #205']),
#  '206': set(['US 206', 'US 70 & US 206']),
#  '3': set(['Main St #3']),
#  '302': set(['Route 73 North, Suite 302']),
#  '312': set(['312']),
#  '315': set(['Heritage Center Dr #315']),
#  '33': set(['33', 'Route 33']),
#  '37th': set(['N 37th']),
#  '38': set(['New Jersey 38', 'Route 38', 'State Route 38']),
#  '39th': set(['N 39th']),
#  '40': set(['1140 US Highway 40', 'Rt 40']),
#  '4080': set(['4080']),
#  '41st': set(['S. 41st']),
#  '43rd': set(['N 43rd']),
#  '446-1234': set(['1 Brookline BlvdHavertown, PA 19083(610) 446-1234']),
#  '452': set(['Market Street; Pennsylvania Route 452',
#              'Pennel Road; Pennsylvania Route 452']),
#  '5': set(['West Girard Avenue, 5']),
#  '53rd': set(['N 53rd']),
#  '651': set(['W Ridge Pike #651']),
#  '70': set(['State Route 70', 'US 70']),
#  '73': set(['New Jersey 73', 'North Route 73', 'Route 73', 'State Route 73']),
#  '80': set(['N Lewis RD Unit #80']),
#  '902': set(['Chestnut Street #902']),
#  'A': set(['S Bethlehem Pike #A']),
#  'AVE': set(['EDGMONT AVE']),
#  'Acres': set(['Lane of Acres']),
#  'Alley': set(['Borton Alley',
#                'Bradford Alley',
#                'Commerce Alley',
#                'Elfreths Alley',
#                'Hillard Alley',
#                'Hopkins Alley',
#                'Horners Alley',
#                'Lumbermill Alley',
#                'Marple Mill Alley',
#                'Matlack Alley',
#                'Milford Cr Alley',
#                'Milstoke Alley',
#                'Stokes Alley',
#                'Waterway Alley',
#                'Willings Alley']),
#  'Ashleypreston': set(['Ashleypreston']),
#  'Atreet': set(['Arch Atreet']),
#  'Audubon': set(['John James Audubon']),
#  'Ave': set([' 3822 Ridge Ave',
#              '517 W Girard Ave',
#              '72nd Ave and Orgontz Ave',
#              '8401 Frankford Ave',
#              'Alden Ave',
#              'Aramingo Ave',
#              'Bala Ave',
#              'Baltimore Ave',
#              'Bishop Ave, Clifton Ave',
#              'Bryn Mawr Ave',
#              'Chester Ave',
#              'Constitution Ave',
#              'Cottman Ave',
#              'Devon St & Mt. Pleasant Ave',
#              'E Butler Ave',
#              'E Lancaster Ave',
#              'E. Mt Airy Ave',
#              'East Lancaster Ave',
#              'East Wadsworth Ave',
#              'Essington Ave',
#              'Fairmount Ave',
#              'Fort Washington Ave',
#              'Frankford Ave',
#              'Germantown Ave',
#              'Grays Ave',
#              'Hirst Ave',
#              'Knowles Ave',
#              'Lancaster Ave',
#              'Montgomery Ave',
#              'Mt.Ephraim Ave',
#              'N Olden Ave',
#              'Northwestern Ave',
#              'Park Ave',
#              'Parkway Ave',
#              'Pennington Ave',
#              'Pennsylvania Ave',
#              'Penrose Ave',
#              'Philmont Ave',
#              'Rising Sun Ave',
#              'S Clinton Ave',
#              'S Washington Ave',
#              'S. Clinton Ave',
#              'Sharon Ave',
#              'Sloan Ave',
#              'Stenton Ave',
#              'Summit Ave',
#              'Towamencin Ave',
#              'W Cheltenham Ave',
#              'W Magnolia Ave',
#              'Washington Ave',
#              'West Butler Ave',
#              'West Girard Ave',
#              'West Glenside Ave',
#              'West Huntington Ave',
#              'West Mermaid Lane and Germantown Ave',
#              'West Montgomery Ave',
#              'West Trenton Ave']),
#  'Ave.': set(['Aramingo Ave.',
#               'Baltimore Ave.',
#               'Bonny Brook Ave.',
#               'East Butler Ave.',
#               'Germantown Ave.',
#               'Morton Ave.',
#               'Station Ave.',
#               'Taylor Ave.']),
#  'B': set(['Salem Ave Building B']),
#  'B2': set(['Bristol Pike B2']),
#  'Basin': set(['Lynn Ct Det Basin']),
#  'Bigler': set(['Bigler']),
#  'Blvd': set(['Brookline Blvd',
#               'Centennial Blvd',
#               'Hearthstone Blvd',
#               'Nassau Park Blvd',
#               'Nassau Parl Blvd',
#               'S Christopher Columbus Blvd',
#               'Shannondell Blvd',
#               'W Cuthbert Blvd']),
#  'Blvd.': set(['Brookline Blvd.']),
#  'Bois': set(['Rue Du Bois']),
#  'Broadway': set(['373 North Broadway', 'North Broadway', 'South Broadway']),
#  'Brown': set(['N 37th & Brown']),
#  'Bypass': set(['Pemberton Bypass']),
#  'C': set(['Aramingo Ave #C']),
#  'Center': set(['Alyce Ln-Comm Center', 'Greentree Center', 'Town Center']),
#  'Centura': set(['Centura']),
#  'Chanticleer': set(['Chanticleer']),
#  'Chestnut': set(['Chestnut']),
#  'Chippendale': set(['Chippendale']),
#  'Cir': set(['Woodfield Cir']),
#  'Circle': set(['Bayhill Circle',
#                 'Beauport Circle',
#                 'Candlewood Circle',
#                 'Charlann Circle',
#                 'Chateau Circle',
#                 'College Circle',
#                 'Concord Circle',
#                 'Crestview Circle',
#                 'Dorchester Circle',
#                 'Dumont Circle',
#                 'Exton Circle',
#                 'Falcon Circle',
#                 'Fireside Circle',
#                 'Four Crown Royal Circle',
#                 'Franklin Mills Circle',
#                 'Glenn Circle',
#                 'Grand Banks Circle',
#                 'Hanby Circle',
#                 'Harrow Circle',
#                 'Huxley Circle',
#                 'Inverness Circle',
#                 'Lady Diana Circle',
#                 'Lexington Circle',
#                 'Masters Circle',
#                 'Meadowview Circle',
#                 'Merion Circle',
#                 'Milford Circle',
#                 'Nolen Circle',
#                 'Pacadilly Circle',
#                 'Paine Circle',
#                 'Picadilly Circle',
#                 'Pippin Circle',
#                 'Shirley Circle',
#                 'Signers Circle',
#                 'Station Circle',
#                 'Tara Circle',
#                 'Thunder Circle',
#                 'Two Crown Royal Circle',
#                 'Union Circle',
#                 'United States Circle',
#                 'Veterans Circle',
#                 'Wedgewood Circle',
#                 'Wentworth Circle',
#                 'Wynnedale Circle',
#                 'Yarmouth Circle']),
#  'Close': set(['Heaver Close']),
#  'Cove': set(['Grand Banks Cove']),
#  'Cricket': set(['Cricket']),
#  'Croft': set(['Kings Croft']),
#  'Crossing': set(['Harpers Crossing',
#                   'Painters Crossing',
#                   'Prince Charles Crossing']),
#  'Ct': set(['Portsmouth Ct']),
#  'D102': set(['Henry Ave #D102']),
#  'Dr': set(['2515 Metropolitan Dr',
#             'Deerpath Dr',
#             'Kendarbren Dr',
#             'Merrill Lynch Dr',
#             'Revere Dr',
#             "Tommy's Meadow Dr"]),
#  'E': set(['NJ-70 E']),
#  'East': set(['3rd Avenue East',
#               'Cabot Boulevard East',
#               'Clementon Road East',
#               'Coventry Circle East',
#               'E High Street East',
#               'Essex Court East',
#               'Halifax Court East',
#               'High Street East',
#               'Kings Highway East',
#               'Lincoln Drive East',
#               'Marlton Pike East',
#               'North Independence Mall East',
#               'Old Marlton Pike East',
#               'Route 38 East',
#               'South Independence Mall East',
#               'State Route 70 East']),
#  'Extension': set(['Spruce Street Extension', 'Washington Street Extension']),
#  'Floor': set(['Race Street 2nd Floor']),
#  'Front': set(['S Front']),
#  'Garden': set(['Spring Garden']),
#  'Glory': set(['Morning Glory']),
#  'Green': set(['Logan Green',
#                'Militia Green',
#                'Monmouth Green',
#                'Whister Green']),
#  'Greene': set(['Greene', 'Township Greene']),
#  'Haverford': set(['Haverford']),
#  'Heights': set(['Hillcrest Heights']),
#  'Highway': set(['East Lincoln Highway',
#                  'Harding Highway',
#                  'Kings Highway',
#                  'Lincoln Highway',
#                  'North Kings Highway',
#                  'Old Lincoln Highway',
#                  'West Kings Highway']),
#  'Hill': set(['Society Hill']),
#  'Hollow': set(['Acorn Hill Hollow', 'Lakeview Hollow']),
#  'Homer': set(['Winslow Homer']),
#  'Horse': set(['White Horse']),
#  'Hutchinson': set(['North Hutchinson']),
#  'Hwy': set(['Harding Hwy', 'Lincoln Hwy']),
#  'Ii': set(['The Woods Ii']),
#  'Jessica': set(['Jessica']),
#  'L': set(['Whispering Pine L']),
#  'Line': set(['Irwins Line']),
#  'Ln': set(['Patricia Ln', 'Simpkins Ln']),
#  'Longwood': set(['Longwood']),
#  'Mall': set(['Montgomery Mall']),
#  'Mallon': set(['Mallon']),
#  'Manor': set(['Brynwood Manor']),
#  'Maple': set(['South Maple']),
#  'Market': set(['Market']),
#  'Marlkress': set(['Marlkress']),
#  'Master': set(['15th and Master']),
#  'Moore': set(['Cecil B. Moore']),
#  'NJ-73': set(['NJ-73']),
#  'Nixon': set(['Shawmont & Nixon']),
#  'North': set(['Birchwood Park Drive North',
#                'Crown Royal Parkway North',
#                'Delsea Drive North',
#                'Elmwood Road North',
#                'Kings Highway North',
#                'Lakeview Drive North',
#                'Lincoln Drive North',
#                'Olney Avenue North',
#                'Pelham Road North',
#                'State Route 73 North']),
#  'Oak': set(['Laurel Oak']),
#  'PA': set(['Baltimore Pike, Springfield, PA',
#             'E Lincoln HwyLanghorne, PA',
#             'E. Lincoln Highway Langhore, PA',
#             'Saxer Ave, Springfield, PA']),
#  'PA.': set(['Trenton Rd - Levittown, PA.']),
#  'PIke': set(['Princeton PIke']),
#  'Park': set(['Falsoa Park', 'Narbrook Park']),
#  'Parrish': set(['Parrish']),
#  'Pike': set(['130 N White Horse Pike',
#               '2nd Street Pike',
#               'Baltimore Pike',
#               'Bethlehem Pike',
#               'Black Horse Pike',
#               'Bridgeton Pike',
#               'Bridgetown Pike',
#               'Bristol Pike',
#               'Brunswick Pike',
#               'Burlington Pike',
#               'Butler Pike',
#               'Concord Pike',
#               'DeKalb Pike',
#               'East Germantown Pike',
#               'East Ridge Pike',
#               'Germantown Pike',
#               'Huntingdon Pike',
#               'Limekiln Pike',
#               'Mantua Pike',
#               'Marlton Pike',
#               'N White Horse Pike',
#               'North Bethlehem Pike',
#               'North White Horse Pike',
#               'Old Marlton Pike',
#               'Penllyn Pike',
#               'Philadelphia Pike',
#               'Princeton Pike',
#               'Ridge Pike',
#               'S Bethlehem Pike',
#               'S Black Horse Pike',
#               'Second Street Pike',
#               'Skippack Pike',
#               'South Bethlehem Pike',
#               'Sumneytown Pike',
#               'W Germantown Pike',
#               'W Ridge Pike',
#               'W. White Horse Pike',
#               'West Baltimore Pike',
#               'West Chester Pike',
#               'West Dekalb Pike',
#               'West Germantown Pike',
#               'West Marlton Pike',
#               'West Point Pike',
#               'West Ridge Pike',
#               'White Horse Pike',
#               'Wilmington Pike']),
#  'Plaza': set(['Carnegie Plaza',
#                'Cooper Plaza',
#                'Dothan Plaza',
#                'Two Bala Plaza']),
#  'Preston': set(['Ashley Preston', 'N Preston']),
#  'Provence': set(['En Provence']),
#  'R1404': set(['901 N. Penn Street Unit R1404']),
#  'ROAD': set(['DAVISVILLE ROAD', 'TERWOOD ROAD', 'TOWNSHIP LINE ROAD']),
#  'ROW': set(['Eagle ROW', 'Harrier ROW', 'Ravens ROW']),
#  'Rd': set(['22 Centerton Rd',
#             '24 Centerton Rd',
#             '40 Centerton Rd',
#             '52 Centerton Rd',
#             '58 Centerton Rd',
#             '62 Centerton Rd',
#             '66 Centerton Rd',
#             '70 Centerton Rd',
#             'Abrams Mill Rd',
#             'Almshouse Rd',
#             'Anderson Rd',
#             "Arney's Mount Rd",
#             'Barren Hill Rd',
#             'Briarwood Rd',
#             'Bristol Rd',
#             'Byberry Rd',
#             'Church Rd',
#             'Clements Bridge Rd',
#             'Conestoga Rd',
#             'Cross Keys Rd',
#             'Darby Rd',
#             'Deptford Center Rd',
#             'Dilworthtown Rd',
#             'Durham Rd',
#             'E County Line Rd',
#             'Easton Rd',
#             'Edison Furlong Rd',
#             'Evesham Rd',
#             'Grove Rd',
#             'Haddonfield Rd',
#             'Hulmeville Rd',
#             'Hurffville  Rd',
#             'Hurffville Rd',
#             'Kimberton Rd',
#             'King Rd',
#             'Lincoln Mill Rd',
#             'Meetinghouse Rd',
#             'N Providence Rd',
#             'New Falls Rd',
#             'Old Cuthbert Rd',
#             'Russell Mill Rd',
#             'S Easton Rd',
#             'Schuylkill Rd',
#             'South Easton Rd',
#             'Sproul Rd',
#             'Stokes Rd',
#             'Trenton Rd',
#             'Valley Rd',
#             'W Bristol Rd',
#             'Woodmount Rd',
#             'York Rd']),
#  'Rd.': set(['Kagey Rd.',
#              'N. Lewis Rd.',
#              'North Lewis Rd.',
#              'S. Chester Rd.',
#              'Wistar Rd.',
#              'York Rd.']),
#  'Re': set(['Browning Ln Re']),
#  'Reno': set(['North 50th Street & Reno']),
#  'Reten': set(['Knottingham Reten']),
#  'Ridge': set(['Redstone Ridge']),
#  'Royal': set(['Five Crown Royal']),
#  'Run': set(['Ashley Run',
#              'Autumn River Run',
#              'Barton Run',
#              'Chipley Run',
#              'Kettle Run',
#              'Lexton Run',
#              'Pheasant Run',
#              'Rymill Run']),
#  'ST': set(['S 6TH ST']),
#  'Salina': set(['Salina']),
#  'Sheffield': set(['Sheffield']),
#  'Sloan': set(['John Sloan', 'Sloan']),
#  'South': set(['Birchwood Park Drive South',
#                'Crown Royal Parkway South',
#                'Elizaeth Court South',
#                'Euston Road South',
#                'Forsythia Drive South',
#                'Lakeview Drive South',
#                'Pelham Road South',
#                'Route 130 South',
#                'State Route 73 South',
#                'Steel Road South']),
#  'Space': set(['Alyce Ln-Open Space',
#                'Borton Ave-Op Space',
#                'Borton Ave-Open Space',
#                'Festival Dr-Open Space',
#                'Matlack Dr-Open Space',
#                'Merryton-Open Space',
#                'Milford Cr-Open Space']),
#  'Spruce': set(['Spruce']),
#  'Sstreet': set(['South 9th Sstreet']),
#  'St': set(['46th and Market St',
#             '507 E Tulpehocken St',
#             'Baring St',
#             'Bush St',
#             'Carson St',
#             'Center St',
#             'Chestnut St',
#             'Cooper St',
#             'Dekalb St',
#             'Dickinson St',
#             'E Hampton St',
#             'E Hector St',
#             'E Penn St',
#             'E State St',
#             'E. Passyunk Ave and Kauffman St',
#             'Federal St',
#             'Front St & Tasker St',
#             'Green St',
#             'Johnston St',
#             'Market St',
#             'McKean St',
#             'N 3rd St',
#             'N 4th St',
#             'N 5th St',
#             'N 6th St',
#             'N Broad St',
#             'N Gratz St',
#             'N Main St',
#             'North Broad St',
#             'North Front St',
#             'Quarry St',
#             'Race St',
#             'Ranstead St',
#             'Rhawn St',
#             'S 20th St',
#             'S 22nd St',
#             'S 24th St',
#             'S 28th St',
#             'S 3rd St',
#             'S 41st St',
#             'S 47th St',
#             'S 4th St',
#             'S 50th St',
#             'S Broad St',
#             'S Main St',
#             'S Norwood St',
#             'South 40th St',
#             'South Bancroft St',
#             'South St',
#             'South St Bernard St',
#             'Spring Garden St',
#             'St John St',
#             'Starr St',
#             'Swede St',
#             'W Ritner St',
#             'Walnut St',
#             'Washington St',
#             'West Main St']),
#  'St.': set(['12th St.',
#              'Almond St.',
#              'Diamond St.',
#              'E. State St.',
#              'Mt. Pleasant Ave, Devon St, Sprague St.',
#              'N 24th St.',
#              'S. 15th St.',
#              'S. 40th St.',
#              'S. Front St.',
#              'South Broad St.',
#              'W. State St.']),
#  'Steet': set(['South 18th Steet']),
#  'Stev': set(['Old Stev']),
#  'Stiles': set(['16th and Stiles']),
#  'StreetPhiladelphia': set(['117 South 18th StreetPhiladelphia']),
#  'Streets': set(['North 13th and Brown Streets']),
#  'Sts.': set(['1st and Seneca Sts.']),
#  'Sycamore': set(['North Sycamore']),
#  'Ter': set(['Greenview Ter']),
#  'Terrace': set(['Alfa Terrace',
#                  'Azalea Terrace',
#                  'Balfield Terrace',
#                  'Beverly Terrace',
#                  'Blue Jay Terrace',
#                  'Byron Terrace',
#                  'Cricket Terrace',
#                  'Dalton Terrace',
#                  'Dothan Terrace',
#                  'Douglas Terrace',
#                  'Eleanor Terrace',
#                  'Elm Terrace',
#                  'Eustace Terrace',
#                  'Hadleigh Terrace',
#                  'Henfield Terrace',
#                  'Lakeview Terrace',
#                  'Lee Terrace',
#                  'Main St Terrace',
#                  'McClenachan Terrace',
#                  'Moonlight Terrace',
#                  'Morrill Terrace',
#                  'Oak Terrace',
#                  'Pine Terrace',
#                  'Pleasant View Terrace',
#                  'Rymill Terrace',
#                  'Sandringham Terrace',
#                  'Saxby Terrace',
#                  'Tara Terrace',
#                  'Tinder Box Terrace',
#                  'Tracey Terrace',
#                  'Treebark Terrace',
#                  'Ward Terrace',
#                  'Washington Terrace',
#                  'Wexford Terrace']),
#  'Thompson': set(['Sletcher and Thompson']),
#  'Trees': set(['Lane Of Trees']),
#  'Turn': set(['Tranquility Turn']),
#  'Turnpike': set(['Pennsylvania Turnpike']),
#  'US-130': set(['US-130']),
#  'Versailles': set(['Versailles']),
#  'Vine': set(['12th and Vine']),
#  'W': set(['NJ 70 W', 'State Route 70 W']),
#  'W5': set(['Presidential Blvd, Ste W5']),
#  'Walk': set(['Country Walk',
#               'Hamilton Walk',
#               'Liacouras Walk',
#               'Locust Walk',
#               'Polett Walk',
#               'Woodland Walk']),
#  'Warren': set(['Warren']),
#  'Way': set(['Alcott Way',
#              'Amenity Way',
#              'American Way',
#              'Andrew Wyeth Way',
#              'Andy Warhol Way',
#              "Ann's Choice Way",
#              'Apple Way',
#              'Applied Card Way',
#              'Arbor Way',
#              'Artisan Way',
#              'Ashley Way',
#              'Azalea Way',
#              'Bellows Way',
#              'Benchly Way',
#              'Bennett Way',
#              'Berkshire Way',
#              'Bradford Way',
#              'Brantley Way',
#              'Braxton Way',
#              'Cambridge Way',
#              'Candlewyck Way',
#              'Commons Way',
#              'Delancey Way',
#              'Delicious Way',
#              'Eagle Way',
#              'Eaton Way',
#              'Eldon Way',
#              'Foundry Way',
#              'Freedoms Way',
#              'George Bellows Way',
#              'George Bingham Way',
#              'Georgia Okeefe Way',
#              'Gilbert Stuart Way',
#              'Golf Club Way',
#              'Grant Wood Way',
#              'Green Tree Way',
#              'Green Valley Way',
#              'Greentree Way',
#              'Gregorys Way',
#              'Hessian Way',
#              'Hollybrook Way',
#              'Independence Way',
#              'Janton Way',
#              'Jasper Johns Way',
#              'Jennifer Way',
#              'Jillians Way',
#              'John James Audubon Way',
#              'John Singer Sargent Way',
#              'Johnnys Way',
#              'Kevin Way',
#              'Lafrance Way',
#              'Lantern Way',
#              'Links Way',
#              'Lucretia Mott Way',
#              'Majestic Way',
#              'Maple Way',
#              'Mather Way',
#              'Merchants Way',
#              'Nina Way',
#              'Norman Rockwell Way',
#              'Nottingham Way',
#              'Peter Hurd Way',
#              'Plaza Way',
#              'Ravenswood Way',
#              'Reading Way',
#              'Roberts Way',
#              'Rock Way',
#              'Ross Way',
#              'Salem Way',
#              'Scout Way',
#              'St Jean Way',
#              'Stafford Way',
#              'Technology Way',
#              'Thomas Eakins Way',
#              'Triumphe Way',
#              'Upland Way',
#              "Veteran's Way",
#              'Walden Way',
#              'Westtown Way',
#              'Wharton Way',
#              'Wilderness Way',
#              'Willow Brook Way',
#              'Wimbledon Way',
#              'Winding Way',
#              'Winfield Way',
#              'Winslow Homer Way',
#              'Winston Way',
#              'Woodview Way']),
#  'West': set(['Benjamin West',
#               'Cabot Boulevard West',
#               'Chapel Avenue West',
#               'Coventry Circle West',
#               'Doris Drive West',
#               'Elizabeth Court West',
#               'Euston Road West',
#               'Haddon Court West',
#               'Jackson Court West',
#               'Jarrett Court West',
#               'Kings Highway West',
#               'Lincoln Drive West',
#               'Marlton Pike West',
#               'North Independence Mall West',
#               'Old Marlton Pike West',
#               'State Route 70 West',
#               'White Horse Road West']),
#  'Woods': set(['The Woods']),
#  'al': set(['pullen al']),
#  'ave': set(['Ridge ave',
#              'and 1891 brunswick ave',
#              'hillcrest ave',
#              'michigan ave']),
#  'avenue': set(['Ohio avenue']),
#  'drive': set(['Bucks Town drive']),
#  'ext': set(['brunswick ave ext']),
#  'king': set(['West king']),
#  'rd': set(['Cricket rd', 'Lawrenceville rd']),
#  'road': set(['Morehall road', 'Newtown-Langhorne road']),
#  'south': set(['Route 130 south']),
#  'st': set(['Main st',
#             'centre st',
#             'clay st',
#             'e front st',
#             'e state st',
#             'jackson st',
#             'livingston st',
#             'market st',
#             'mercer st',
#             'pear st',
#             's 3rd st',
#             's broad st',
#             's montgomery st',
#             's stockton st',
#             's warren st',
#             'st',
#             'w state st']),
#  'st.': set(['E. State st.']),
#  'street': set(['9th street',
#                 'Broad street',
#                 'East ontario street',
#                 'Westmoreland street',
#                 'chestnut street',
#                 'tilton street']),
#  'susquahana': set(['thompson and susquahana']),
#  'way': set(['mortgage way'])}

# %% [markdown]
# From the list, we can see that 'St.' and 'St' are needed to updated to 'Street', 'Ln' to 'Lane', 'Rd' to 'Road', and etc. There are also misspelling in street names:"Line" should be written as "Lane". In addition, some address contains the state name and they need to be removed. The following program make the update and print out the results:

# %%
mapping = { "St": "Street",
            "St.": "Street",
           "Sstreet":"Street",
            "Ave": "Avenue",
           "Ave.": "Avenue",
             "avenue": "Avenue",
            "ave": "Avenue",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
           "blvd": "Boulevard",
            "Bouevard": "Boulevard",
            "Boulavard": "Boulevard",
            "Boulvard": "Boulevard",
            "Rd.": "Road",
            "Rd": "Road",
           "RD": "Road",
           "rd": "Road",
           "road": "Road",
            "st": "Street",
           "Street.": "Street", 
           "street": "Street",
           "Sts":"Street",
           "Pkwy": "Parkway", 
           "Ct": "Court", 
           "Cir": "Circle",
           "Dr": "Drive", 
           "Dr.": "Drive", 
           "Hwy": "Highway",
           "Hwy.": "Highway",
           "Ln": "Lane",
           "Line":"Lane",
           "L":"Lane",
            "Ln.": "Lane",
           "PIke":"Pike",
            "Pl": "Place",
           "PLACE": "Place",
           "place":"Place",
            "Plz": "Plaza",
            "Rd": "Road",
            "Rd.": "Road",
            "St": "Street",
            "St.": "Street",
            "st": "Street",
           "ST": "Street",
            "street": "Street",
            "square": "Square",
            "parkway": "Parkway",
            "N.": "North",
            "N": "North",
            "E.": "East",
            "E": "East",
            "S.": "South",
            "S": "South",
            "W.": "West",
            "W": "West",
           "way":"Way"
            }

def update_name(name, mapping):

    # YOUR CODE HERE
    m=street_type_re.search(name)
    if m not in expected:
        if m.group() in mapping.keys():
            name = re.sub(m.group(), mapping[m.group()], name)
    name = re.split(",|\#|\-",name)[0]
    return name
    

st_types = audit(OSMFILE)

# %%
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# White Horse => White Horse
# Redstone Ridge => Redstone Ridge
# 1 Brookline BlvdHavertown, PA 19083(610) 446-1234 => 1 Brookline BlvdHavertown
# Pennel Road; Pennsylvania Route 452 => Pennel Road; Pennsylvania Route 452
# Market Street; Pennsylvania Route 452 => Market Street; Pennsylvania Route 452
# Hillcrest Heights => Hillcrest Heights
# 52 Centerton Rd => 52 Centerton Road
# Clements Bridge Rd => Clements Bridge Road
# 58 Centerton Rd => 58 Centerton Road
# E County Line Rd => E County Line Road
# Darby Rd => Darby Road
# Stokes Rd => Stokes Road
# Conestoga Rd => Conestoga Road
# Church Rd => Church Road
# York Rd => York Road
# Dilworthtown Rd => Dilworthtown Road
# 62 Centerton Rd => 62 Centerton Road
# South Easton Rd => South Easton Road
# Durham Rd => Durham Road
# Lincoln Mill Rd => Lincoln Mill Road
# Evesham Rd => Evesham Road
# Anderson Rd => Anderson Road
# Barren Hill Rd => Barren Hill Road
# Valley Rd => Valley Road
# W Bristol Rd => W Bristol Road
# Bristol Rd => Bristol Road
# 24 Centerton Rd => 24 Centerton Road
# Edison Furlong Rd => Edison Furlong Road
# Easton Rd => Easton Road
# Hulmeville Rd => Hulmeville Road
# 70 Centerton Rd => 70 Centerton Road
# Grove Rd => Grove Road
# 22 Centerton Rd => 22 Centerton Road
# Hurffville Rd => Hurffville Road
# Arney's Mount Rd => Arney's Mount Road
# Russell Mill Rd => Russell Mill Road
# S Easton Rd => S Easton Road
# Kimberton Rd => Kimberton Road
# Almshouse Rd => Almshouse Road
# Woodmount Rd => Woodmount Road
# N Providence Rd => N Providence Road
# 66 Centerton Rd => 66 Centerton Road
# New Falls Rd => New Falls Road
# Old Cuthbert Rd => Old Cuthbert Road
# Haddonfield Rd => Haddonfield Road
# Deptford Center Rd => Deptford Center Road
# Sproul Rd => Sproul Road
# Meetinghouse Rd => Meetinghouse Road
# Abrams Mill Rd => Abrams Mill Road
# Byberry Rd => Byberry Road
# Briarwood Rd => Briarwood Road
# Trenton Rd => Trenton Road
# Hurffville  Rd => Hurffville  Road
# 40 Centerton Rd => 40 Centerton Road
# Schuylkill Rd => Schuylkill Road
# Cross Keys Rd => Cross Keys Road
# King Rd => King Road
# Browning Ln Re => Browning Ln Re
# Society Hill => Society Hill
# Ohio avenue => Ohio Avenue
# N 37th & Brown => N 37th & Brown
# Cricket => Cricket
# Grand Banks Cove => Grand Banks Cove
# Lane Of Trees => Lane Of Trees
# Old Stev => Old Stev
# S Front => S Front
# Arch Atreet => Arch Atreet
# TERWOOD ROAD => TERWOOD ROAD
# TOWNSHIP LINE ROAD => TOWNSHIP LINE ROAD
# DAVISVILLE ROAD => DAVISVILLE ROAD
# Winslow Homer => Winslow Homer
# South 9th Sstreet => South 9th Street
# N 53rd => N 53rd
# Morning Glory => Morning Glory
# Whispering Pine L => Whispering Pine Lane
# Tranquility Turn => Tranquility Turn
# N 37th => N 37th
# Princeton PIke => Princeton Pike
# Cecil B. Moore => Cecil B. Moore
# East Trenton Avenue Morrisville, PA 19067 => East Trenton Avenue Morrisville
# Chippendale => Chippendale
# Knottingham Reten => Knottingham Reten
# Marple Mill Alley => Marple Mill Alley
# Willings Alley => Willings Alley
# Milford Cr Alley => Milford Cr Alley
# Hopkins Alley => Hopkins Alley
# Lumbermill Alley => Lumbermill Alley
# Bradford Alley => Bradford Alley
# Hillard Alley => Hillard Alley
# Borton Alley => Borton Alley
# Commerce Alley => Commerce Alley
# Waterway Alley => Waterway Alley
# Horners Alley => Horners Alley
# Matlack Alley => Matlack Alley
# Stokes Alley => Stokes Alley
# Elfreths Alley => Elfreths Alley
# Milstoke Alley => Milstoke Alley
# Presidential Blvd, Ste W5 => Presidential Blvd
# Bristol Pike B2 => Bristol Pike B2
# 373 North Broadway => 373 North Broadway
# North Broadway => North Broadway
# South Broadway => South Broadway
# Trenton Rd - Levittown, PA. => Trenton Rd
# Warren => Warren
# Rue Du Bois => Rue Du Bois
# Kings Croft => Kings Croft
# Kings Highway West => Kings Highway West
# Jackson Court West => Jackson Court West
# Doris Drive West => Doris Drive West
# Elizabeth Court West => Elizabeth Court West
# Benjamin West => Benjamin West
# Jarrett Court West => Jarrett Court West
# State Route 70 West => State Route 70 West
# North Independence Mall West => North Independence Mall West
# Chapel Avenue West => Chapel Avenue West
# Lincoln Drive West => Lincoln Drive West
# Marlton Pike West => Marlton Pike West
# Cabot Boulevard West => Cabot Boulevard West
# White Horse Road West => White Horse Road West
# Haddon Court West => Haddon Court West
# Euston Road West => Euston Road West
# Coventry Circle West => Coventry Circle West
# Old Marlton Pike West => Old Marlton Pike West
# Heritage Center Dr #315 => Heritage Center Dr
# chestnut street => chestnut Street
# Broad street => Broad Street
# 9th street => 9th Street
# tilton street => tilton Street
# Westmoreland street => Westmoreland Street
# East ontario street => East ontario Street
# South Clinton Avenue Ste. 111 => South Clinton Avenue Ste. 111
# S 6TH ST => S 6TH Street
# Pemberton Bypass => Pemberton Bypass
# John Sloan => John Sloan
# Sloan => Sloan
# NJ-70 E => NJ
# Pippin Circle => Pippin Circle
# Picadilly Circle => Picadilly Circle
# Fireside Circle => Fireside Circle
# Crestview Circle => Crestview Circle
# Dumont Circle => Dumont Circle
# Exton Circle => Exton Circle
# Glenn Circle => Glenn Circle
# Four Crown Royal Circle => Four Crown Royal Circle
# Huxley Circle => Huxley Circle
# Falcon Circle => Falcon Circle
# Signers Circle => Signers Circle
# Wentworth Circle => Wentworth Circle
# Merion Circle => Merion Circle
# Candlewood Circle => Candlewood Circle
# Veterans Circle => Veterans Circle
# Beauport Circle => Beauport Circle
# Dorchester Circle => Dorchester Circle
# Masters Circle => Masters Circle
# Bayhill Circle => Bayhill Circle
# Inverness Circle => Inverness Circle
# Lexington Circle => Lexington Circle
# Grand Banks Circle => Grand Banks Circle
# Milford Circle => Milford Circle
# Charlann Circle => Charlann Circle
# Franklin Mills Circle => Franklin Mills Circle
# College Circle => College Circle
# Two Crown Royal Circle => Two Crown Royal Circle
# Nolen Circle => Nolen Circle
# Harrow Circle => Harrow Circle
# Yarmouth Circle => Yarmouth Circle
# Lady Diana Circle => Lady Diana Circle
# Wynnedale Circle => Wynnedale Circle
# Station Circle => Station Circle
# Paine Circle => Paine Circle
# Wedgewood Circle => Wedgewood Circle
# United States Circle => United States Circle
# Shirley Circle => Shirley Circle
# Concord Circle => Concord Circle
# Hanby Circle => Hanby Circle
# Union Circle => Union Circle
# Meadowview Circle => Meadowview Circle
# Tara Circle => Tara Circle
# Pacadilly Circle => Pacadilly Circle
# Thunder Circle => Thunder Circle
# Chateau Circle => Chateau Circle
# North Independence Mall East => North Independence Mall East
# South Independence Mall East => South Independence Mall East
# 3rd Avenue East => 3rd Avenue East
# Halifax Court East => Halifax Court East
# Route 38 East => Route 38 East
# Coventry Circle East => Coventry Circle East
# Clementon Road East => Clementon Road East
# E High Street East => E High Street East
# Lincoln Drive East => Lincoln Drive East
# High Street East => High Street East
# Old Marlton Pike East => Old Marlton Pike East
# Marlton Pike East => Marlton Pike East
# State Route 70 East => State Route 70 East
# Essex Court East => Essex Court East
# Cabot Boulevard East => Cabot Boulevard East
# Kings Highway East => Kings Highway East
# Upland Ave #118 => Upland Ave
# Chestnut => Chestnut
# Route 130 south => Route 130 south
# Pheasant Run => Pheasant Run
# Barton Run => Barton Run
# Kettle Run => Kettle Run
# Autumn River Run => Autumn River Run
# Rymill Run => Rymill Run
# Lexton Run => Lexton Run
# Chipley Run => Chipley Run
# Ashley Run => Ashley Run
# Jessica => Jessica
# Sheffield => Sheffield
# US 206 => US 206
# US 70 & US 206 => US 70 & US 206
# Narbrook Park => Narbrook Park
# Falsoa Park => Falsoa Park
# Lawrenceville rd => Lawrenceville Road
# Cricket rd => Cricket Road
# Main St #3 => Main St
# Saxer Ave, Springfield, PA => Saxer Ave
# Baltimore Pike, Springfield, PA => Baltimore Pike
# E. Lincoln Highway Langhore, PA => E. Lincoln Highway Langhore
# E Lincoln HwyLanghorne, PA => E Lincoln HwyLanghorne
# 312 => 312
# Irwins Line => Irwins Lane
# Harrier ROW => Harrier ROW
# Eagle ROW => Eagle ROW
# Ravens ROW => Ravens ROW
# Aramingo Ave #C => Aramingo Ave
# East Butler Ave. => East Butler Avenue
# Morton Ave. => Morton Avenue
# Germantown Ave. => Germantown Avenue
# Baltimore Ave. => Baltimore Avenue
# Station Ave. => Station Avenue
# Taylor Ave. => Taylor Avenue
# Aramingo Ave. => Aramingo Avenue
# Bonny Brook Ave. => Bonny Brook Avenue
# Washington Street Extension => Washington Street Extension
# Spruce Street Extension => Spruce Street Extension
# 901 N. Penn Street Unit R1404 => 901 N. Penn Street Unit R1404
# Route 73 North, Suite 302 => Route 73 North
# Two Bala Plaza => Two Bala Plaza
# Dothan Plaza => Dothan Plaza
# Cooper Plaza => Cooper Plaza
# Carnegie Plaza => Carnegie Plaza
# thompson and susquahana => thompson and susquahana
# Greene => Greene
# Township Greene => Township Greene
# 15th and Master => 15th and Master
# Logan Green => Logan Green
# Whister Green => Whister Green
# Militia Green => Militia Green
# Monmouth Green => Monmouth Green
# 1st and Seneca Sts. => 1st and Seneca Sts.
# E Lancaster Ave => E Lancaster Avenue
# Germantown Ave => Germantown Avenue
# Northwestern Ave => Northwestern Avenue
# Aramingo Ave => Aramingo Avenue
# 517 W Girard Ave => 517 W Girard Avenue
# Rising Sun Ave => Rising Sun Avenue
# Pennington Ave => Pennington Avenue
# Knowles Ave => Knowles Avenue
# Bala Ave => Bala Avenue
# Frankford Ave => Frankford Avenue
# Fairmount Ave => Fairmount Avenue
# Alden Ave => Alden Avenue
# Lancaster Ave => Lancaster Avenue
# E Butler Ave => E Butler Avenue
# Baltimore Ave => Baltimore Avenue
# 8401 Frankford Ave => 8401 Frankford Avenue
# Pennsylvania Ave => Pennsylvania Avenue
# West Montgomery Ave => West Montgomery Avenue
# Towamencin Ave => Towamencin Avenue
# Sloan Ave => Sloan Avenue
# Fort Washington Ave => Fort Washington Avenue
# Devon St & Mt. Pleasant Ave => Devon St & Mt. Pleasant Avenue
# S. Clinton Ave => S. Clinton Avenue
# Essington Ave => Essington Avenue
# Sharon Ave => Sharon Avenue
# Montgomery Ave => Montgomery Avenue
# Grays Ave => Grays Avenue
# S Clinton Ave => S Clinton Avenue
# Penrose Ave => Penrose Avenue
# West Huntington Ave => West Huntington Avenue
# W Cheltenham Ave => W Cheltenham Avenue
# Mt.Ephraim Ave => Mt.Ephraim Avenue
# N Olden Ave => N Olden Avenue
# Hirst Ave => Hirst Avenue
# Summit Ave => Summit Avenue
# W Magnolia Ave => W Magnolia Avenue
# Washington Ave => Washington Avenue
# Chester Ave => Chester Avenue
# Constitution Ave => Constitution Avenue
# 72nd Ave and Orgontz Ave => 72nd Avenue and Orgontz Avenue
# E. Mt Airy Ave => E. Mt Airy Avenue
# Parkway Ave => Parkway Avenue
# Stenton Ave => Stenton Avenue
# West Butler Ave => West Butler Avenue
# Bryn Mawr Ave => Bryn Mawr Avenue
# Philmont Ave => Philmont Avenue
# West Glenside Ave => West Glenside Avenue
# Park Ave => Park Avenue
# Cottman Ave => Cottman Avenue
# West Trenton Ave => West Trenton Avenue
# East Lancaster Ave => East Lancaster Avenue
# West Mermaid Lane and Germantown Ave => West Mermaid Lane and Germantown Avenue
# West Girard Ave => West Girard Avenue
# Bishop Ave, Clifton Ave => Bishop Avenue
# East Wadsworth Ave => East Wadsworth Avenue
#  3822 Ridge Ave =>  3822 Ridge Avenue
# S Washington Ave => S Washington Avenue
# Shawmont & Nixon => Shawmont & Nixon
# Chestnut Street #902 => Chestnut Street
# 16th and Stiles => 16th and Stiles
# Henry Ave #D102 => Henry Ave
# 200 Manor Ave. Langhorne, PA 19047 => 200 Manor Ave. Langhorne
# 2275 E Lincoln Hwy, Langhorne, PA 19047 => 2275 E Lincoln Hwy
# 2245 E. Lincoln Hwy, Langhorne, PA 19047 => 2245 E. Lincoln Hwy
# 2300  East Lincoln Highway, Pennsylvania 19047 => 2300  East Lincoln Highway
# 12th and Vine => 12th and Vine
# Montgomery Mall => Montgomery Mall
# Mallon => Mallon
# The Woods => The Woods
# Ashleypreston => Ashleypreston
# Spruce => Spruce
# EDGMONT AVE => EDGMONT AVE
# Centura => Centura
# Newtown-Langhorne road => Newtown
# Morehall road => Morehall Road
# Salina => Salina
# NJ 70 W => NJ 70 West
# State Route 70 W => State Route 70 West
# NJ-73 => NJ
# S. 15th St. => S. 15th Street
# Almond St. => Almond Street
# S. Front St. => S. Front Street
# W. State St. => W. Streette Street
# N 24th St. => N 24th Street
# South Broad St. => South Broad Street
# Mt. Pleasant Ave, Devon St, Sprague St. => Mt. Pleasant Ave
# 12th St. => 12th Street
# Diamond St. => Diamond Street
# S. 40th St. => S. 40th Street
# E. State St. => E. Streette Street
# John James Audubon => John James Audubon
# Five Crown Royal => Five Crown Royal
# Haverford => Haverford
# Lane of Acres => Lane of Acres
# N 39th => N 39th
# Acorn Hill Hollow => Acorn Hill Hollow
# Lakeview Hollow => Lakeview Hollow
# Benchly Way => Benchly Way
# Azalea Way => Azalea Way
# Mather Way => Mather Way
# Nottingham Way => Nottingham Way
# Westtown Way => Westtown Way
# Kevin Way => Kevin Way
# Thomas Eakins Way => Thomas Eakins Way
# Andy Warhol Way => Andy Warhol Way
# Wimbledon Way => Wimbledon Way
# Jennifer Way => Jennifer Way
# Woodview Way => Woodview Way
# Salem Way => Salem Way
# Green Valley Way => Green Valley Way
# Peter Hurd Way => Peter Hurd Way
# Lafrance Way => Lafrance Way
# Applied Card Way => Applied Card Way
# Roberts Way => Roberts Way
# Johnnys Way => Johnnys Way
# Candlewyck Way => Candlewyck Way
# Majestic Way => Majestic Way
# Ann's Choice Way => Ann's Choice Way
# Greentree Way => Greentree Way
# Veteran's Way => Veteran's Way
# George Bellows Way => George Bellows Way
# Rock Way => Rock Way
# Green Tree Way => Green Tree Way
# Bradford Way => Bradford Way
# John James Audubon Way => John James Audubon Way
# Hollybrook Way => Hollybrook Way
# Nina Way => Nina Way
# Golf Club Way => Golf Club Way
# Janton Way => Janton Way
# Jillians Way => Jillians Way
# John Singer Sargent Way => John Singer Sargent Way
# Upland Way => Upland Way
# Arbor Way => Arbor Way
# Georgia Okeefe Way => Georgia Okeefe Way
# Ravenswood Way => Ravenswood Way
# Plaza Way => Plaza Way
# Lantern Way => Lantern Way
# Triumphe Way => Triumphe Way
# Wharton Way => Wharton Way
# Bennett Way => Bennett Way
# Braxton Way => Braxton Way
# Apple Way => Apple Way
# Foundry Way => Foundry Way
# Grant Wood Way => Grant Wood Way
# St Jean Way => St Jean Way
# Alcott Way => Alcott Way
# Delancey Way => Delancey Way
# Links Way => Links Way
# Winding Way => Winding Way
# Eldon Way => Eldon Way
# Delicious Way => Delicious Way
# Ashley Way => Ashley Way
# Merchants Way => Merchants Way
# Cambridge Way => Cambridge Way
# Winfield Way => Winfield Way
# Walden Way => Walden Way
# Reading Way => Reading Way
# Norman Rockwell Way => Norman Rockwell Way
# Commons Way => Commons Way
# Winston Way => Winston Way
# Scout Way => Scout Way
# Wilderness Way => Wilderness Way
# Stafford Way => Stafford Way
# Maple Way => Maple Way
# Amenity Way => Amenity Way
# Gregorys Way => Gregorys Way
# Willow Brook Way => Willow Brook Way
# Berkshire Way => Berkshire Way
# Artisan Way => Artisan Way
# Independence Way => Independence Way
# Jasper Johns Way => Jasper Johns Way
# Technology Way => Technology Way
# Gilbert Stuart Way => Gilbert Stuart Way
# Winslow Homer Way => Winslow Homer Way
# Brantley Way => Brantley Way
# American Way => American Way
# Eagle Way => Eagle Way
# Freedoms Way => Freedoms Way
# Eaton Way => Eaton Way
# Bellows Way => Bellows Way
# Lucretia Mott Way => Lucretia Mott Way
# Ross Way => Ross Way
# George Bingham Way => George Bingham Way
# Hessian Way => Hessian Way
# Andrew Wyeth Way => Andrew Wyeth Way
# Lynn Ct Det Basin => Lynn Ct Det Basin
# Crown Royal Parkway North => Crown Royal Parkway North
# Olney Avenue North => Olney Avenue North
# Pelham Road North => Pelham Road North
# State Route 73 North => State Route 73 North
# Delsea Drive North => Delsea Drive North
# Lakeview Drive North => Lakeview Drive North
# Birchwood Park Drive North => Birchwood Park Drive North
# Kings Highway North => Kings Highway North
# Lincoln Drive North => Lincoln Drive North
# Elmwood Road North => Elmwood Road North
# E. State st. => E. State st.
# Alyce Ln-Open Space => Alyce Ln
# Matlack Dr-Open Space => Matlack Dr
# Merryton-Open Space => Merryton
# Festival Dr-Open Space => Festival Dr
# Borton Ave-Op Space => Borton Ave
# Borton Ave-Open Space => Borton Ave
# Milford Cr-Open Space => Milford Cr
# US-130 => US
# Buck Rd #2 => Buck Rd
# 117 South 18th StreetPhiladelphia => 117 South 18th StreetPhiladelphia
# W Ridge Pike #651 => W Ridge Pike
# Parrish => Parrish
# Brookline Blvd. => Brookline Boulevard
# En Provence => En Provence
# East Ridge Pike => East Ridge Pike
# Marlton Pike => Marlton Pike
# Skippack Pike => Skippack Pike
# Bridgeton Pike => Bridgeton Pike
# East Germantown Pike => East Germantown Pike
# West Ridge Pike => West Ridge Pike
# Bridgetown Pike => Bridgetown Pike
# West Germantown Pike => West Germantown Pike
# West Dekalb Pike => West Dekalb Pike
# 2nd Street Pike => 2nd Street Pike
# W. White Horse Pike => W. White Horse Pike
# Butler Pike => Butler Pike
# West Point Pike => West Point Pike
# Burlington Pike => Burlington Pike
# West Chester Pike => West Chester Pike
# W Ridge Pike => W Ridge Pike
# Old Marlton Pike => Old Marlton Pike
# Baltimore Pike => Baltimore Pike
# Bethlehem Pike => Bethlehem Pike
# Brunswick Pike => Brunswick Pike
# Black Horse Pike => Black Horse Pike
# S Bethlehem Pike => S Bethlehem Pike
# Concord Pike => Concord Pike
# Huntingdon Pike => Huntingdon Pike
# Princeton Pike => Princeton Pike
# West Marlton Pike => West Marlton Pike
# Second Street Pike => Second Street Pike
# DeKalb Pike => DeKalb Pike
# Germantown Pike => Germantown Pike
# North Bethlehem Pike => North Bethlehem Pike
# S Black Horse Pike => S Black Horse Pike
# North White Horse Pike => North White Horse Pike
# South Bethlehem Pike => South Bethlehem Pike
# W Germantown Pike => W Germantown Pike
# N White Horse Pike => N White Horse Pike
# Wilmington Pike => Wilmington Pike
# Ridge Pike => Ridge Pike
# West Baltimore Pike => West Baltimore Pike
# Philadelphia Pike => Philadelphia Pike
# 130 N White Horse Pike => 130 N White Horse Pike
# Mantua Pike => Mantua Pike
# Penllyn Pike => Penllyn Pike
# Limekiln Pike => Limekiln Pike
# White Horse Pike => White Horse Pike
# Bristol Pike => Bristol Pike
# Sumneytown Pike => Sumneytown Pike
# Salem Ave Building B => Salem Ave Building B
# mortgage way => mortgage Way
# South 18th Steet => South 18th Steet
# North Hutchinson => North Hutchinson
# Johnston St => Johnston Street
# Green St => Green Street
# Spring Garden St => Spring Garden Street
# Quarry St => Quarry Street
# S Broad St => S Broad Street
# S Norwood St => S Norwood Street
# S 22nd St => S 22nd Street
# Dickinson St => Dickinson Street
# Dekalb St => Dekalb Street
# Ranstead St => Ranstead Street
# S 4th St => S 4th Street
# E State St => E Streetate Street
# Washington St => Washington Street
# South St Bernard St => South Street Bernard Street
# Market St => Market Street
# 46th and Market St => 46th and Market Street
# E. Passyunk Ave and Kauffman St => E. Passyunk Ave and Kauffman Street
# N 6th St => N 6th Street
# S 50th St => S 50th Street
# N Gratz St => N Gratz Street
# S 3rd St => S 3rd Street
# N 5th St => N 5th Street
# N 3rd St => N 3rd Street
# S Main St => S Main Street
# Chestnut St => Chestnut Street
# Rhawn St => Rhawn Street
# E Penn St => E Penn Street
# West Main St => West Main Street
# Baring St => Baring Street
# South St => South Street
# N 4th St => N 4th Street
# South Bancroft St => South Bancroft Street
# Center St => Center Street
# E Hector St => E Hector Street
# Race St => Race Street
# Starr St => Streetarr Street
# Federal St => Federal Street
# South 40th St => South 40th Street
# Front St & Tasker St => Front Street & Tasker Street
# Carson St => Carson Street
# St John St => Street John Street
# North Front St => North Front Street
# S 20th St => S 20th Street
# 507 E Tulpehocken St => 507 E Tulpehocken Street
# Walnut St => Walnut Street
# Cooper St => Cooper Street
# S 28th St => S 28th Street
# S 47th St => S 47th Street
# S 41st St => S 41st Street
# North Broad St => North Broad Street
# Swede St => Swede Street
# Bush St => Bush Street
# N Main St => N Main Street
# N Broad St => N Broad Street
# S 24th St => S 24th Street
# E Hampton St => E Hampton Street
# W Ritner St => W Ritner Street
# McKean St => McKean Street
# State Route 38 => State Route 38
# Route 38 => Route 38
# New Jersey 38 => New Jersey 38
# Marlton Pike East Ste. 168 => Marlton Pike East Ste. 168
# Pennsylvania Turnpike => Pennsylvania Turnpike
# West king => West king
# Lancaster Avenue #17 => Lancaster Avenue
# Ashley Preston => Ashley Preston
# N Preston => N Preston
# North 13th and Brown Streets => North 13th and Brown Streets
# Country Walk => Country Walk
# Hamilton Walk => Hamilton Walk
# Liacouras Walk => Liacouras Walk
# Woodland Walk => Woodland Walk
# Polett Walk => Polett Walk
# Locust Walk => Locust Walk
# 33 => 33
# Route 33 => Route 33
# Heaver Close => Heaver Close
# Greenview Ter => Greenview Ter
# Market => Market
# Portsmouth Ct => Portsmouth Court
# 4080 => 4080
# Race Street 2nd Floor => Race Street 2nd Floor
# Simpkins Ln => Simpkins Lane
# Patricia Ln => Patricia Lane
# Laurel Oak => Laurel Oak
# pullen al => pullen al
# Sletcher and Thompson => Sletcher and Thompson
# michigan ave => michigan Avenue
# and 1891 brunswick ave => and 1891 brunswick Avenue
# Ridge ave => Ridge Avenue
# hillcrest ave => hillcrest Avenue
# N 43rd => N 43rd
# Harding Highway => Harding Highway
# Lincoln Highway => Lincoln Highway
# East Lincoln Highway => East Lincoln Highway
# North Kings Highway => North Kings Highway
# Old Lincoln Highway => Old Lincoln Highway
# Kings Highway => Kings Highway
# West Kings Highway => West Kings Highway
# Greentree Center => Greentree Center
# Alyce Ln-Comm Center => Alyce Ln
# Town Center => Town Center
# Kagey Rd. => Kagey Road
# S. Chester Rd. => S. Chester Road
# York Rd. => York Road
# North Lewis Rd. => North Lewis Road
# Wistar Rd. => Wistar Road
# N. Lewis Rd. => N. Lewis Road
# Spring Garden => Spring Garden
# Brynwood Manor => Brynwood Manor
# Marlkress => Marlkress
# Rt 40 => Rt 40
# 1140 US Highway 40 => 1140 US Highway 40
# Bloomfield Dr, Unit 1 => Bloomfield Dr
# S Newtown Street Rd #1 => S Newtown Street Rd
# Sansom St #1 => Sansom St
# Walnut St #1 => Walnut St
# Route 1 => Route 1
# West Girard Avenue, 5 => West Girard Avenue
# Versailles => Versailles
# Lincoln Hwy => Lincoln Highway
# Harding Hwy => Harding Highway
# Merrill Lynch Dr => Merrill Lynch Drive
# Kendarbren Dr => Kendarbren Drive
# Deerpath Dr => Deerpath Drive
# Tommy's Meadow Dr => Tommy's Meadow Drive
# 2515 Metropolitan Dr => 2515 Metropolitan Drive
# Revere Dr => Revere Drive
# S Bethlehem Pike #A => S Bethlehem Pike
# Office Center Dr #205 => Office Center Dr
# Chanticleer => Chanticleer
# North Sycamore => North Sycamore
# Bigler => Bigler
# New Jersey 73 => New Jersey 73
# Route 73 => Route 73
# State Route 73 => State Route 73
# North Route 73 => North Route 73
# Longwood => Longwood
# US 70 => US 70
# State Route 70 => State Route 70
# Painters Crossing => Painters Crossing
# Prince Charles Crossing => Prince Charles Crossing
# Harpers Crossing => Harpers Crossing
# Euston Road South => Euston Road South
# Lakeview Drive South => Lakeview Drive South
# Crown Royal Parkway South => Crown Royal Parkway South
# State Route 73 South => State Route 73 South
# Route 130 South => Route 130 South
# Birchwood Park Drive South => Birchwood Park Drive South
# Pelham Road South => Pelham Road South
# Elizaeth Court South => Elizaeth Court South
# Steel Road South => Steel Road South
# Forsythia Drive South => Forsythia Drive South
# N Lewis RD Unit #80 => N Lewis RD Unit
# Woodfield Cir => Woodfield Circle
# S. 41st => S. 41st
# Bucks Town drive => Bucks Town drive
# North 50th Street & Reno => North 50th Street & Reno
# pear st => pear Street
# livingston st => livingStreeton Street
# s broad st => s broad Street
# jackson st => jackson Street
# s 3rd st => s 3rd Street
# s warren st => s warren Street
# w state st => w Streetate Street
# st => Street
# centre st => centre Street
# s stockton st => s Streetockton Street
# e state st => e Streetate Street
# mercer st => mercer Street
# e front st => e front Street
# clay st => clay Street
# market st => market Street
# s montgomery st => s montgomery Street
# Main st => Main Street
# The Woods Ii => The Woods Ii
# brunswick ave ext => brunswick ave ext
# Pleasant View Terrace => Pleasant View Terrace
# Elm Terrace => Elm Terrace
# Eleanor Terrace => Eleanor Terrace
# Tracey Terrace => Tracey Terrace
# Tinder Box Terrace => Tinder Box Terrace
# Lakeview Terrace => Lakeview Terrace
# Byron Terrace => Byron Terrace
# Azalea Terrace => Azalea Terrace
# Moonlight Terrace => Moonlight Terrace
# Wexford Terrace => Wexford Terrace
# Sandringham Terrace => Sandringham Terrace
# Ward Terrace => Ward Terrace
# Washington Terrace => Washington Terrace
# Henfield Terrace => Henfield Terrace
# Eustace Terrace => Eustace Terrace
# Treebark Terrace => Treebark Terrace
# Cricket Terrace => Cricket Terrace
# Oak Terrace => Oak Terrace
# McClenachan Terrace => McClenachan Terrace
# Douglas Terrace => Douglas Terrace
# Dothan Terrace => Dothan Terrace
# Beverly Terrace => Beverly Terrace
# Hadleigh Terrace => Hadleigh Terrace
# Tara Terrace => Tara Terrace
# Dalton Terrace => Dalton Terrace
# Main St Terrace => Main St Terrace
# Saxby Terrace => Saxby Terrace
# Balfield Terrace => Balfield Terrace
# Rymill Terrace => Rymill Terrace
# Morrill Terrace => Morrill Terrace
# Blue Jay Terrace => Blue Jay Terrace
# Pine Terrace => Pine Terrace
# Alfa Terrace => Alfa Terrace
# Lee Terrace => Lee Terrace
# Centennial Blvd => Centennial Boulevard
# Nassau Parl Blvd => Nassau Parl Boulevard
# Nassau Park Blvd => Nassau Park Boulevard
# Brookline Blvd => Brookline Boulevard
# Hearthstone Blvd => Hearthstone Boulevard
# W Cuthbert Blvd => W Cuthbert Boulevard
# Shannondell Blvd => Shannondell Boulevard
# S Christopher Columbus Blvd => S Christopher Columbus Boulevard
# South Maple => South Maple

# %% [markdown]
# Here we can see that all the issue with street names are updated.

# %% [markdown]
# ## 3. Prepare SQL Database

# %% [markdown]
# After data cleaning, we save the nodes, tags, and ways into csv file and import into sqlite to create a database containing these tables.

# %% [markdown]
# ## 4. Data Overview

# %% [markdown]
# The sizes of files used in the project are as follows:

# %% [markdown]
# |File Name                      |        Size     |
# |-------------------------------|-----------------|
# |Philadelphia_pennsylvania.osm  |  737.1 MB       |
# |philadelphia.db                |  531.4 MB       |
# |nodes.csv                      |  274.8 MB       |
# |nodes_tags.csv                 |  20.2 MB        |
# |ways_nodes.csv                 |  94.6 MB        |
# |ways.csv                       |  20.6 MB        |
# |ways_tags.csv                  |  54.1 MB        |

# %% [markdown]
# Other statistics explored using sqlite3:

# %%
import csv, sqlite3
con = sqlite3.connect("philadelphia.db")
cur = con.cursor()

# %% [markdown]
# Number of nodes in the data:

# %%
result=cur.execute('SELECT COUNT(*) FROM nodes')
result.fetchone()[0]
# Out:
# 3289070

# %% [markdown]
# Number of ways in the data:

# %%
result = cur.execute('SELECT COUNT(*) FROM ways')
result.fetchone()[0]
# Out:
# 343066

# %% [markdown]
# Number of unique users:

# %%
result = cur.execute('SELECT COUNT(DISTINCT(e.uid)) \
            FROM (SELECT uid FROM nodes UNION ALL SELECT uid FROM ways) e')
result.fetchall()[0]
# Out:
# (2340,)

# %% [markdown]
# ## 5. Data Exploration

# %% [markdown]
# Number of common ammenities in the data:

# %%
cur.execute('SELECT value, COUNT(*) as num \
            FROM nodes_tags \
            WHERE key="amenity" \
            GROUP BY value \
            ORDER BY num DESC \
            LIMIT 10').fetchall()
# Out:
# [(u'school', 1613),
#  (u'restaurant', 1024),
#  (u'place_of_worship', 704),
#  (u'fire_station', 439),
#  (u'fast_food', 396),
#  (u'bench', 378),
#  (u'social_facility', 279),
#  (u'parking', 245),
#  (u'fuel', 244),
#  (u'cafe', 238)]

# %% [markdown]
# We can see that the top 1 ammenity in Philadelphia is school, which has 1613. And restaurant follows with 1024 locations.

# %% [markdown]
# Number of popular cuisines in the city:

# %%
cur.execute('SELECT nodes_tags.value, COUNT(*) as num \
            FROM nodes_tags \
                JOIN (SELECT DISTINCT(id) FROM nodes_tags WHERE value="restaurant") i \
                ON nodes_tags.id=i.id \
            WHERE nodes_tags.key="cuisine" \
            GROUP BY nodes_tags.value \
            ORDER BY num DESC\
            LIMIT 10').fetchall()
# Out:
# [(u'pizza', 119),
#  (u'italian', 56),
#  (u'chinese', 49),
#  (u'mexican', 41),
#  (u'american', 39),
#  (u'sandwich', 28),
#  (u'burger', 18),
#  (u'asian', 17),
#  (u'indian', 12),
#  (u'japanese', 12)]

# %% [markdown]
# We can see that the cuisine people like the most in Philadelphia is pizza, next is italian and the third is chinese food.

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# The OpenStreetMap data of Philadelphia is of good quality. We found some typos in street spelling and some address contain city and state names as well as inconsistency in abbreviations in the street type. We spent a significant amount of time checking different fields and cleaning the dataset. However, there are still a lot of extra work needed to improve the data quality of this extract.
#
# ### Suggestions for standardizing street names and control typos:
# - We can work on some preset rules for data imput. Preset the common names selection, such as "Street", "Place", "Lane", "Pike", "Parkway", etc.
# - We can develop a function to automatically clean the data periodically. This may be tedious at first, but with all data imput well controlled and database well maintained, the database will be easier to use and users do not need to spend a lot of time working on data cleaning.

# %% [markdown]
# # 7. Files

# %% [markdown]
# - Philadelphia_pennsylvania.osm: data downloaded from the OpenStreetMap project
# - audit.py: audit and update street names
# - data.py: parse and shape the osm data and create CSV files from OSM dataset
# - dbwrite.py: read in the CSV files and create sql database
# - mapparser.py: find unique tags in the data
# - query.py: data exploration using sqlite
